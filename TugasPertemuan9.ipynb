# %%
# 1. Diberikan list berikut:
buah = ["apel", "mangga", "jeruk", "anggur", "pisang"]
#print(buah)

# a. Tambahkan 'semangka' di akhir list
buah.append("semangka")
print(f"buah setelah ditambah\t : {buah}")

# b. Sisipkan 'durian' di antara 'jeruk' dan 'anggur'
buah.insert(3, "durian")
print(f"buah setelah disisipkan\t : {buah}")

# c. Hapus 'mangga' dari list
buah.remove("mangga")
print(f"buah setelah dihapus\t : {buah}")

# d. Ubah 'pisang' menjadi 'nanas'
buah[4] = "nanas"
print(f"buah setelah diubah\t : {buah}")

# e. Tampilkan 3 buah pertama
buah_pertama = buah[:3]
print(f"tiga buah pertama\t : {buah_pertama}")

# 2. Diberikan list berikut:
angka = [45, 12, 78, 23, 56, 89, 34]
#print(angka)

# a. Urutkan list secara ascending
angka.sort()
print(f"\nsetelah diurutkan secara ascending : {angka}")

# b. Urutkan list secara descending
angka.reverse()
print(f"setelah di balik\t : {angka}")
# Out:
# buah setelah ditambah	 : ['apel', 'mangga', 'jeruk', 'anggur', 'pisang', 'semangka']
# buah setelah disisipkan	 : ['apel', 'mangga', 'jeruk', 'durian', 'anggur', 'pisang', 'semangka']
# buah setelah dihapus	 : ['apel', 'jeruk', 'durian', 'anggur', 'pisang', 'semangka']
# buah setelah diubah	 : ['apel', 'jeruk', 'durian', 'anggur', 'nanas', 'semangka']
# tiga buah pertama	 : ['apel', 'jeruk', 'durian']
#
# setelah diurutkan secara ascending : [12, 23, 34, 45, 56, 78, 89]
# setelah di balik	 : [89, 78, 56, 45, 34, 23, 12]
